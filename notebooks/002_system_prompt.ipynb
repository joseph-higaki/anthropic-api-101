# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic
client = Anthropic()

# %%
model = "claude-haiku-4-5"
max_tokens = 100

# %% [markdown]
# # System Prompt

# %%
system_prompt = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system_prompt=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }
    
    if system_prompt:
        params["system"] = system_prompt
    
    message = client.messages.create(**params)
    return message.content[0].text

# %% [markdown]
# ## With System Prompt

# %%
messages = []
add_user_message(messages,"How do I solve 5x+3=2 for x")
answer = chat(messages, system_prompt)
print(answer)
# Out:
# Great question! Let's work through this step by step.
#
# **Step 1:** What is your goal here?
# Think about what you're trying to find - you want to get `x` by itself on one side of the equation.
#
# **Step 2:** Looking at the equation `5x + 3 = 2`, what's attached to the `x` term right now?
# - There's the coefficient 5 (multiplied by x)
# - There's also a 3 being added
#
# Which one should we remove first to isolate the `x` term? (Hint: It's usually easier to undo addition/subtraction before multiplication/division)
#
# What do you think we should do?

# %% [markdown]
# ## WithOUT System Prompt

# %%
messages = []
add_user_message(messages,"How do I solve 5x+3=2 for x")
answer = chat(messages)
print(answer)
# Out:
# # Solving 5x + 3 = 2
#
# **Step 1:** Subtract 3 from both sides
# $$5x + 3 - 3 = 2 - 3$$
# $$5x = -1$$
#
# **Step 2:** Divide both sides by 5
# $$x = -\frac{1}{5}$$
#
# **Answer:** $x = -0.2$ (or $-\frac{1}{5}$)

# %% [markdown]
# # Excercise Sys Prompt:

# %%
messages = []
add_user_message(messages,"Write a python function that checks a string for duplicate characters")
answer = chat(messages, system_prompt="Choose first approach only. Do not comment or document function. return function string only")
print(answer)
# Out:
# ```python
# def has_duplicates(s):
#     return len(s) != len(set(s))
# ```

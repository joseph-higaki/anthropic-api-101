# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()
dataset

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %% [markdown]
# ## Code Graders

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(test_case, output):
    format = test_case["format"]
    if format == "json":
        return validate_json(output)
    elif format == "python":
        return validate_python(output)
    else:
        return validate_regex(output)

# %% [markdown]
# ## MOdel Graders

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Here is the Criteria to Evaluate the solutin:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
    Please solve the following task:

    {test_case["task"]}
    * Respond only with Python, JSON, or a plain Regex
    * Do not add any comments or commentary or explanation
    """ 
    
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(test_case, output)
    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning
    }

from statistics import mean

def run_eval(dataset):
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")
    
    return results

# %% [markdown]
# ## INspecting the test datasets

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.166666666666666

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\n{\n  \"FunctionName\": \"S3EventProcessor\",\n  \"Runtime\": \"python3.11\",\n  \"Role\": \"arn:aws:iam::ACCOUNT_ID:role/lambda-execution-role\",\n  \"Handler\": \"index.handler\",\n  \"Timeout\": 60,\n  \"MemorySize\": 256,\n  \"Environment\": {\n    \"Variables\": {\n      \"DYNAMODB_TABLE_NAME\": \"events-table\",\n      \"LOG_LEVEL\": \"INFO\"\n    }\n  },\n  \"EventSourceMappings\": [\n    {\n      \"EventSource\": \"s3:ObjectCreated:*\",\n      \"Filter\": {\n        \"Key\": {\n          \"FilterRules\": [\n            {\n              \"Name\": \"prefix\",\n              \"Value\": \"uploads/\"\n            },\n            {\n              \"Name\": \"suffix\",\n              \"Value\": \".json\"\n            }\n          ]\n        }\n      }\n    }\n  ]\n}\n",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that processes S3 events, with environment variables for a DynamoDB table name and log level",
#       "format": "json",
#       "solution_criteria": "Valid JSON with Lambda function configuration, S3 event source mapping, environment variables section containing DynamoDB table name and log level"
#     },
#     "score": 8.0,
#     "reasoning": "The solution demonstrates good understanding of Lambda configuration and environment variables, meeting the core criteria with proper DynamoDB table name and log level setup. However, it contains a structural error in how S3 event sources are configured\u2014EventSourceMappings should not be a direct Lambda property. S3 bucket notifications require separate configuration via S3 bucket notification settings or Lambda permissions, not through the Lambda function configuration itself. The placeholder IAM role would also prevent actual deployment."
#   },
#   {
#     "output": "\nimport re\n\ndef parse_s3_path(s3_path):\n    \"\"\"\n    Parse an AWS S3 object key path and return a dictionary with bucket name and object key.\n    \n    Supports formats:\n    - s3://bucket-name/object-key\n    - bucket-name/object-key\n    \"\"\"\n    # Match s3:// prefix format\n    s3_url_pattern = r'^s3://([^/]+)/(.+)$'\n    match = re.match(s3_url_pattern, s3_path)\n    \n    if match:\n        return {\n            'bucket': match.group(1),\n            'key': match.group(2)\n        }\n    \n    # Match bucket/key format (no s3:// prefix)\n    simple_pattern = r'^([^/]+)/(.+)$'\n    match = re.match(simple_pattern, s3_path)\n    \n    if match:\n        return {\n            'bucket': match.group(1),\n            'key': match.group(2)\n        }\n    \n    # If no key is present, treat entire path as bucket\n    return {\n        'bucket': s3_path,\n        'key': None\n    }\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS S3 object key path and returns a dictionary with the bucket name and object key separated",
#       "format": "python",
#       "solution_criteria": "Function accepts S3 path string (e.g., 'my-bucket/path/to/object'), returns dict with 'bucket' and 'key' keys, handles edge cases like missing slashes"
#     },
#     "score": 8.5,
#     "reasoning": "The solution successfully meets the core requirements by parsing both common S3 path formats and returning the expected dictionary structure. It handles the edge case of missing slashes, though arguably too permissively. The main limitation is lack of input validation and error handling for truly malformed paths. Consider raising ValueError for invalid formats rather than silent fallback behavior, and optionally validate bucket naming conventions."
#   },
#   {
#     "output": "\n^arn:aws:iam::\\d{12}:role/[\\w+=,.@-]+$\n",
#     "test_case": {
#       "task": "Create a regular expression that matches valid AWS IAM role ARNs in the format arn:aws:iam::account-id:role/role-name",
#       "format": "regex",
#       "solution_criteria": "Regex pattern matches valid IAM role ARNs, validates 12-digit account IDs, allows alphanumeric and hyphen characters in role names, rejects malformed ARNs"
#     },
#     "score": 8.0,
#     "reasoning": "The regex successfully matches the basic ARN structure and validates the critical components (12-digit account ID, proper prefix). However, it is overly permissive with role name characters by allowing special characters in any position and lacking length validation. AWS IAM role names have stricter rules: they must start with alphanumeric or hyphen, be 1-64 characters long, and can only contain alphanumeric characters, hyphens, and underscores. The current pattern would incorrectly accept `arn:aws:iam::123456789012:role/+invalid` or `arn:aws:iam::123456789012:role/` (empty role name)."
#   }
# ]

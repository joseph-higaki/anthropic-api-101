# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

generate 3 objects.
"""
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()
dataset

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %% [markdown]
# ## Code Graders

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(test_case, output):
    format = test_case["format"]
    if format == "json":
        return validate_json(output)
    elif format == "python":
        return validate_python(output)
    else:
        return validate_regex(output)

# %% [markdown]
# ## MOdel Graders

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Here is the Criteria to Evaluate the solutin:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
    Please solve the following task:

    {test_case["task"]}
    * Respond only with Python, JSON, or a plain Regex
    * Do not add any comments or commentary or explanation
    """ 
    
    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(test_case, output)
    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning
    }

from statistics import mean

def run_eval(dataset):
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")
    
    return results

# %% [markdown]
# ## INspecting the test datasets

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.5

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport json\nimport re\nimport sys\n\ndef extract_s3_bucket_ids(template_content):\n    try:\n        template = json.loads(template_content)\n        s3_bucket_ids = [\n            logical_id for logical_id, resource in template.get('Resources', {}).items()\n            if resource.get('Type') == 'AWS::S3::Bucket'\n        ]\n        return s3_bucket_ids\n    except json.JSONDecodeError:\n        return []\n\nif __name__ == \"__main__\":\n    template_content = sys.stdin.read()\n    result = extract_s3_bucket_ids(template_content)\n    print(json.dumps(result))\n",
#     "test_case": {
#       "task": "Parse an AWS CloudFormation template and extract all resource logical IDs that have type 'AWS::S3::Bucket'",
#       "format": "python",
#       "solution_criteria": "Function should take a CloudFormation JSON/dict as input and return a list of logical IDs for S3 bucket resources. Should handle nested structures correctly."
#     },
#     "score": 8.0,
#     "reasoning": "The solution correctly solves the stated task for JSON CloudFormation templates with a straightforward approach. However, it has notable limitations: it doesn't support YAML (a standard CloudFormation format), lacks error visibility, and includes unused imports. The criteria mention 'nested structures' but the solution only checks top-level Resources, which is actually correct for CloudFormation's structure. The implementation is functional but could be more robust and production-ready."
#   },
#   {
#     "output": "\nimport json\n\npolicy = {\n    \"Version\": \"2012-10-17\",\n    \"Statement\": [\n        {\n            \"Effect\": \"Allow\",\n            \"Action\": [\n                \"s3:GetObject\",\n                \"s3:PutObject\"\n            ],\n            \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n        }\n    ]\n}\n\nprint(json.dumps(policy, indent=2))\n",
#     "test_case": {
#       "task": "Create a JSON policy document that allows a principal to perform s3:GetObject and s3:PutObject actions on all objects in an S3 bucket named 'my-data-bucket'",
#       "format": "json",
#       "solution_criteria": "Valid IAM policy JSON with correct Statement structure, Effect set to 'Allow', Action array containing both s3:GetObject and s3:PutObject, and Resource ARN matching all objects in the specified bucket."
#     },
#     "score": 3.5,
#     "reasoning": "The solution meets the core criteria by producing a valid IAM policy document with correct structure, proper Effect setting, required actions, and accurate resource ARN. However, the policy is missing the Principal element, which is necessary for most practical IAM use cases (though it may be acceptable if intended for inline role policies). The code is functional but lacks robustness and clarity."
#   },
#   {
#     "output": "\nimport re\n\ndef extract_iam_role_arns(text):\n    pattern = r'arn:aws:iam::\\d{12}:role/[a-zA-Z0-9\\-_./]+'\n    matches = re.findall(pattern, text)\n    return matches\n\ndef validate_iam_role_arn(arn):\n    pattern = r'^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9\\-_./]+$'\n    return bool(re.match(pattern, arn))\n",
#     "test_case": {
#       "task": "Write a regex pattern to validate and extract AWS IAM role ARNs from a text string",
#       "format": "regex",
#       "solution_criteria": "Pattern should match valid IAM role ARNs in format 'arn:aws:iam::ACCOUNT-ID:role/ROLE-NAME' and capture the account ID and role name components."
#     },
#     "score": 8.0,
#     "reasoning": "The solution correctly identifies and matches valid IAM role ARN formats and includes both validation and extraction functions. However, it fails to meet the explicit criteria requirement to 'capture the account ID and role name components' as separate groups. The regex patterns use findall() and match() which return full strings rather than capture groups. To fully satisfy the criteria, the solution should use capturing groups like (\\d{12}) and ([a-zA-Z0-9\\-_.]+) to extract individual components, and the functions should return structured data (dictionaries or tuples) with these separate parts."
#   }
# ]

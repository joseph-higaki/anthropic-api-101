# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic
client = Anthropic()

# %%
model = "claude-haiku-4-5"
max_tokens = 100

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=max_tokens,
        messages=messages,
    )
    return message.content[0].text

# %%
messages = []
add_user_message(messages,"Explain MCP for non IT background people? Answer in one sentence")

answer = chat(messages)

add_assistant_message(messages, answer)

add_user_message(messages,"Write another sentence")

final_answer = chat(messages)

# %%
answer
# Out:
# '# MCP Explained Simply\n\nMCP (Model Context Protocol) is a set of rules that allows different software programs to talk to each other and share information in a standardized way, like how all power outlets follow the same design so different appliances can plug in and work.'

# %%
final_answer
# Out:
# '# MCP Explained Simply\n\nMCP (Model Context Protocol) is a set of rules that allows different software programs to talk to each other and share information in a standardized way, like how all power outlets follow the same design so different appliances can plug in and work. Instead of each program needing to learn a unique way to communicate, MCP creates a common language so AI assistants and other tools can seamlessly work together.'

# %% [markdown]
# # Looping Chat

# %%
messages = []
while True:
    user_input = input("> ")
    print("> ", user_input)
    add_user_message(messages, user_input)
    answer = chat(messages)
    add_assistant_message(messages,answer)
    print("---")
    print(answer)
    print("---")
# Out:
# >  1+1
# ---
# 1 + 1 = 2
# ---
# >  add cuatrocientos to that
# ---
# 2 + 400 = 402
#
# (Note: "cuatrocientos" is Spanish for "four hundred")
# ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 messages = []
#       2 while True:
# ----> 3     user_input = input("> ")
#       4     print("> ", user_input)
#       5     add_user_message(messages, user_input)
#       6     answer = chat(messages)
#
# File ~/projects/anthropic-api-101/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~/projects/anthropic-api-101/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

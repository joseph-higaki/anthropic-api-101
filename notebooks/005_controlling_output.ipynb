# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic
client = Anthropic()

# %%
model = "claude-haiku-4-5"
max_tokens = 100

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system_prompt=None, temperature=1.0, stop_sequences=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "temperature": temperature,
        "messages": messages
    }
    
    if system_prompt:
        params["system"] = system_prompt
    
    if stop_sequences:
        params["stop_sequences"] = stop_sequences
    
    
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []
prompt = "Count from 1 to 10"
add_user_message(messages, prompt)
answer = chat(messages, stop_sequences=["5", "3, 4"])
print(answer)
# Out:
# 1, 2,

# %% [markdown]
# ## Excercise
# * Use message prefilling and stop sequences t get 3 different commands in a single response
# * there shouldnt be any comments or explanation
# * hint: message prefilling isnt limited to just '''

# %%
messages = []
prompt = "Generate three different sample of AWS CLI commands. Each should be very short"
add_user_message(messages,prompt)
add_assistant_message(messages, "here are all three commands without comments```bash")
#answer = chat(messages, temperature=0.4)
answer = chat(messages, temperature=0.4, stop_sequences=["```"])
print(answer)
# Out:
# aws s3 ls
#
# aws ec2 describe-instances --region us-east-1
#
# aws dynamodb list-tables

# %%
from IPython.display import Markdown
Markdown(answer)
# Out:
# # Sample 1: List all S3 buckets
# aws s3 ls
#
# # Sample 2: Describe EC2 instances
# aws ec2 describe-instances
#
# # Sample 3: Get current AWS account ID
# aws sts get-caller-identity
